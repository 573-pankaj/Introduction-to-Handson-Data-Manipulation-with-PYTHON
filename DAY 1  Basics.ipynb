# %% [markdown]
# # INTRODUCTIN TO HANDS-ON  DATA MANIPULATION WITH PYTHON
# Welcome to the start of your path to learning how to work with data in the
# [Python programming language!](https://www.python.org/doc/)

# %% [markdown]
# ## DAY 1

# %% [markdown]
# ### Who Created Python ?
#  -[Guido van Rossum](https://en.wikipedia.org/wiki/Guido_van_Rossum)
#   is a Dutch Programmer best known as the creator of the Python programming language

# %% [markdown]
# ## Why Python?
#
# Among the hundreds of programming languages to choose from, we chose to teach you [Python](https://www.python.org/doc/) for the
# following reasons:
#
# - Easy to learn and use (relative to other programming languages).
# - Designed with readability in mind.
# - Excellent tools for handling data efficiently and succinctly(in a brif and clearly expressed manner).
# - Cemented as the world’s [first most popular](https://statisticstimes.com/tech/top-computer-languages.php/)
#   programming language, the most popular scripting language, and an increasing standard for
#   [data analysis in industry](https://medium.com/@data_driven/python-vs-r-for-data-science-and-the-winner-is-3ebb1a968197).
# - General purpose: Initially you will learn Python for data analysis, but it
#   can also used for websites, database management, web scraping, financial
#   modeling, data visualization.
# - Great community support
# - and very switable for those who are very much interested in Scientific Computing

# %% [markdown]
# # Jupyter Notebook

# %% [markdown]
# ***Jupyter Notebook***
#
# This is the actual file that allows you to mix code and text.
#
# The content inside a Jupyter notebook is organized into cells.
#
# Cells can have *inputs* and *outputs*.
#
# There are two main types of cells:
#
# 1. Markdown cells
#   - *Inputs* are written in markdown and can contain formatted text, images, equations, and more.
#   - *Outputs* are rendered **in place of the input** when the cell is executed.
# 1. Code cells
#   - *Inputs* Contain Python code
#   - *Outputs* are placed below the input cell and contain the results generated when the input code is executed.
#
#
# **Why You should be [using](https://medium.com/@ODSC/why-you-should-be-using-jupyter-notebooks-ea2e568c59f2) Jupyter Notebooks**
#
# - The Jupyter Notebook is an open-source web application that allows data scientists to create and share documents that integrate live code, equations, computational output, visualizations, and other multimedia resources, along with explanatory text in a single document.
# - You can use Jupyter Notebooks for all sorts of data science tasks including data cleaning and transformation, numerical simulation, exploratory data analysis, data visualization, statistical modeling, machine learning, deep learning, and much more

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # welcome python

# %% [raw]
# welcom to class

# %% [markdown]
# # PYTHON PROGRAMMING

# %% [markdown]
# # Basics
#
#
#
# **Outcomes**
#
# - Programming concepts
#
#   - Understand variable assignment
#   - Know what a function is and how to figure out what it does
#   - Be able to use tab completion
#
# - Numbers in Python
#
#   - Understand how Python represents numbers
#   - Know the distinction between `int` and `float`
#   - Be familiar with various binary operators for numbers
#   - Introduction to the `math` library
#
# - Text (strings) in Python
#
#   - Understand what a string is and when it is useful
#   - Learn some of the methods associated with strings
#   - Combining strings and output
#
# - True and False (booleans) in Python
#
#   - Understand what a boolean is
#   - Become familiar with all binary operators that return booleans

# %% [markdown]
# # Outline
#
# - [Basics](#Basics)
#   - [First Steps](#First-Steps)
#   - [Functions](#Functions)
#   - [Objects and Types](#Objects-and-Types)
#   - [String Methods](#String-Methods)
#   - [ Numbers](#Numbers)
#   - [Booleans](#Booleans)
#   - [Negation](#Negation)

# %% [markdown]
# # Lets get started

# %% [markdown]
# ## First Steps
# We are ready to begin writing code!
#
# In this section, I will teach you some basic concepts of programming
# and where to search for help.

# %% [markdown]
# ### Variable Assignment
#
# The first thing we will learn is the idea of *variable assignment*.
#
# Variable assignment associates a value to a variable.
#
# Below, we assign the value “Hello World” to the variable `x`

# %%
x = "Hello World"

# %% [markdown]
# Once we have assigned a value to a variable, Python will remember this
# variable as long as the *current* session of Python is still running.
#
# Notice how writing `x` into the prompt below outputs the value
# “Hello World”.

# %%
x
# Out:
# 'Hello World'

# %% [markdown]
#  However, Python returns an error if we ask it about variables that have not yet
# been created.

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9063a9f0e032> in <module>
# ----> 1 y
#
# NameError: name 'y' is not defined

# %% [markdown]
# It is also useful to understand the order in which operations happen.
#
# First, the right side of the equal sign is computed.
#
# Then, that computed value is stored as the variable to the left of the
# equal sign.

# %%
x = 77
print(x)
x = "welcome to Python"
print(x)
# Out:
# 77
# welcome to Python

# %% [markdown]
# ### Code Comments
#
# Comments are short notes that you leave for yourself and for others who read your
# code.
#
# They should be used to explain what the code does.
#
# A comment is made with the `#`. Python ignores everything in a line that follows a `#`.
#
# Let’s practice making some comments.

# %%
i = 1  # Assign the value 1 to variable i
j = 2  # Assign the value 2 to variable j

# We add i and j below this line
i + j
# Out:
# 3

# %% [markdown]
# ## Functions
#
# Functions are processes that take an input (or inputs) and produce an output.
#
# If we had a function called `f` that took two arguments `x` and
# `y`, we would write `f(x, y)` to use the function.
#
# For example, the function `print` simply prints whatever it is given.
# Recall the variable we created called `x`.

# %%
print(x) # PRINT(X) is a function
# Out:
# welcome to Python

# %%
def fun(a):
    print(a)

# %%
fun(7)
# Out:
# 7

# %% [markdown]
# ### Getting Help
#
# We can figure out what a function does by asking for help.
#
# In Jupyter notebooks, this is done by placing a `?` after the function
# name (without using parenthesis) and evaluating the cell.
#
# For example, we can ask for help on the print function by writing
# `print?`.
#
# Depending on how you launched Jupyter, this will either launch
#
# - JupyterLab: display the help in text below the cell.
# - Classic Jupyter Notebooks: display a new panel at the bottom of your
#   screen.  You can exit this panel by hitting the escape key or clicking the x at
#   the top right of the panel.

# %%
print?

# %%
len?

# %% [markdown]
# We will learn much more about functions, including how to write our own, in a
# future lecture.

# %% [markdown]
# ## Objects and Types
#
# Everything in Python is an *object*.
#
# Objects are “things” that contain 1) data and 2) functions that can operate on
# the data.
#
# Sometimes we refer to the functions inside an object as *methods*.
#
# We can investigate what data is inside an object and which methods
# it supports by typing `.` after that particular variable, then
# hitting `TAB`.
#
# It should then list data and method names to the right of the
# variable name like this:
#
# You can scroll through this list by using the up and down arrows.
#
# We often refer to this as “tab completion” or “introspection”.
#
# Let’s do this together below. Keep going down until you find the method
# `split`.

# %%
x
# Out:
# 'welcome to Python'

# %%
 x.split()
# Out:
# ['welcome', 'to', 'Python']

# %% [markdown]
# ### Type function
# The `type` function takes a single argument and outputs the type of
# that argument.

# %%
x = 6.888

# %%
type(x)
# Out:
# float

# %%
type(3)
# Out:
# int

# %%
type("hello world")
# Out:
# str

# %%
type([1,23,3])
# Out:
# list

# %%
type(1.3)
# Out:
# float

# %% [markdown]
# # String Methods
#
# We can use many *methods* to manipulate strings.
#
# We will not be able to cover all of them here, but let’s take a look at
# some of the most useful ones.1

# %%
 X = "RKMVian"

# %%
type(X)
# Out:
# str

# %%
X.upper()
# Out:
# 'RKMVIAN'

# %%
X.lower()
# Out:
# 'rkmvian'

# %%
X.count("R")
# Out:
# 1

# %%
T = "AAAAAAAAAAAAAAAAAAAAAAAAAAAAABBBBBBBCCC"

# %%
T.count("A")
# Out:
# 29

# %%
T.count("B")
# Out:
# 7

# %% [markdown]
# ### String Operations
#
# Some of the arithmetic operators we saw in the numbers lecture also work
# on strings:
#
# - Put two strings together: `x + y`.
# - Repeat the string `x` a total of `n` times: `n * x` (or `x * n`).

# %%
x = "Hello"
y = "World"

# %%
x+y
# Out:
# 'HelloWorld'

# %%
3 * x # prints 3times hello
# Out:
# 'HelloHelloHello'

# %% [markdown]
#  What happens if we try `*` with two strings, or `-` or `/`?
#
# The best way to find out is to try it!

# %%
a = "1"
b = "2"
a * b # string multiplication is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-a23f838afff8> in <module>
#       1 a = "1"
#       2 b = "2"
# ----> 3 a * b # string multiplication is not possible
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
a - b # string subtraction is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-1948218088ff> in <module>
# ----> 1 a - b # string subtraction is not possible
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
a/b # string division is also not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-549ef6e9327d> in <module>
# ----> 1 a/b # string division is also not possible
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %% [markdown]
# # Numbers
#
# Python has two types of numbers.
#
# 1. Integer (`int`): These can only take the values of the integers
#   i.e. $ \{\dots, -2, -1, 0, 1, 2, \dots\} $
# 1. Floating Point Number (`float`): Think of these as any real number
#   such as $ 1.0 $, $ 3.1415 $, or $ -100.022358923223 $…
#
#
# The easiest way to differentiate these types of numbers is to find a decimal place
# after the number.
#
# A float will have a decimal place, but an integer will not.
#
# Below, we assign integers to the variables `xi` and `zi` and assign
# floating point numbers to the variables `xf` and `zf`.1

# %% [markdown]
# xi = 1
# xf = 1.0
# zi = 123
# zf = 1230.5  # Notice -- There are no commas!
# zf2 = 1_230.5  # If needed, we use `_` to separate numbers for readability

# %%
f = 11_11_111 # we can seperate nubers by _
type(f)
# Out:
# int

# %% [markdown]
# ##### By default float division

# %%
12/2    # double / is used for finding the QUOTIENT in float
# Out:
# 6.0

# %% [markdown]
# ##### Make it integer division by using double slash (//)

# %%
12//2    # double // is used for finding the QUOTIENT in int
# Out:
# 6

# %%
37 % 7 # % is used for finding the REMAINDER
# Out:
# 2

# %% [markdown]
# # Booleans
#
# A boolean is a type that denotes true or false.
#
# As you will soon see in the [control flow chapter](control_flow.ipynb), using
# boolean values allows you to perform or skip operations depending on whether or
# not a condition is met.
#
# Let’s start by creating some booleans and looking at them.

# %%
x = True
y = False

type(x)
# Out:
# bool

# %%
x
# Out:
# True

# %%
y
# Out:
# False

# %% [markdown]
# # Negation
#
# Occasionally, determining whether a statement is
# “not true” or “not false” is more convenient than simply “true” or “false”.
#
# This is known as *negating* a statement.
#
# In Python, we can negate a boolean using the word `not`.

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
from IPython.display import Image
Image(filename='Guido-portrait-2014-drc.jpg', width='600')

# %%
from IPython.display import Image
Image(filename='1200px-Python-logo-notext.svg.png', width='500')

# %%
from IPython.display import Image
Image(filename='jupyternotebooklogo.png', width='500')
